# %% [markdown]
# ## EI for LINEAR I. WEEKLY:

# %%
import os
import pandas as pd

# Use current working directory as base
base_dir = os.getcwd()
folder_path = os.path.join(base_dir, "LOG_RETURNS_KALMAN_INTERPOLATED", "weekly")

log_returns = {}

for file in os.listdir(folder_path):
    if file.endswith(".xlsx"):
        file_path = os.path.join(folder_path, file)
        card_name = file.replace(".xlsx", "")
        log_returns[card_name] = pd.read_excel(file_path)

print(f"Loaded {len(log_returns)} log return datasets.")
# Out:
# Loaded 9 log return datasets.

# %%
log_returns.keys()
# Out:
# dict_keys(['weekly_data_aggregated_Charizard-Holo_#11_grade_9', 'weekly_data_aggregated_Charizard-Holo_#4_grade_8_FINAL', 'weekly_data_aggregated_Charizard-Holo_#4_grade_9_FINAL', 'weekly_data_aggregated_Charizard_GX_#9_grade_10', 'weekly_data_aggregated_Full_ArtCharizard_GX_#SV49_grade_10', 'weekly_data_aggregated_Full_ArtCharizard_Vmax_#020_grade_10', 'weekly_data_aggregated_Full_ArtCharizard_Vmax_#SV107_grade_10', 'weekly_data_aggregated_Full_ArtMoltres_&_Zapdos_&_Articuno_GX_#69_(SECRET)_grade_10', 'weekly_data_aggregated_Full_ArtM_Charizard_EX_#101_grade_10'])

# %%
# Replace with any dataset name to preview
sample_card = list(log_returns.keys())[0]  # First dataset
print(f"Preview of {sample_card}:")
print(log_returns[sample_card].head())
# Out:
# Preview of weekly_data_aggregated_Charizard-Holo_#11_grade_9:
#    Date  Log_Returns
# 0     1    -0.151131
# 1     2     0.010052
# 2     3    -0.363843
# 3     4    -0.041622
# 4     5     0.147636

# %%
# !pip install hurst statsmodels numpy pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: hurst in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.0.5)
# Requirement already satisfied: statsmodels in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.14.4)
# Requirement already satisfied: numpy in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.1.2)
# Requirement already satisfied: pandas in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.2.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\janhr\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install fractional
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fractional in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.0.1)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\janhr\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install fdiff
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\janhr\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: fdiff in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.0.0)
# Requirement already satisfied: fontTools>=4.0.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fdiff) (4.54.1)
# Requirement already satisfied: aiohttp>=3.6.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fdiff) (3.11.18)
# Requirement already satisfied: aiodns>=2.0.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fdiff) (3.2.0)
# Requirement already satisfied: aiofiles>=0.4.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fdiff) (24.1.0)
# Requirement already satisfied: rich in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fdiff) (14.0.0)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiodns>=2.0.0->fdiff) (4.6.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp>=3.6.0->fdiff) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp>=3.6.0->fdiff) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp>=3.6.0->fdiff) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp>=3.6.0->fdiff) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp>=3.6.0->fdiff) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp>=3.6.0->fdiff) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp>=3.6.0->fdiff) (1.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->fdiff) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->fdiff) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from markdown-it-py>=2.2.0->rich->fdiff) (0.1.2)
# Requirement already satisfied: cffi>=1.5.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pycares>=4.0.0->aiodns>=2.0.0->fdiff) (1.16.0)
# Requirement already satisfied: idna>=2.0 in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.6.0->fdiff) (3.6)
# Requirement already satisfied: pycparser in c:\users\janhr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi>=1.5.0->pycares>=4.0.0->aiodns>=2.0.0->fdiff) (2.21)

# %% [markdown]
# # !! USE THE FOLLOWING TWO HURST EXPONENTS (the most refined so far):

# %%
from scipy.signal import periodogram
import numpy as np
import statsmodels.api as sm

def gph_estimator(series, m=None):
    series = series.dropna().values
    n = len(series)

    if m is None:
        m = int(n ** 0.6)  # Slightly higher exponent for robustness

    freqs, spectrum = periodogram(series, scaling='spectrum')

    valid_indices = freqs > 0
    freqs = freqs[valid_indices]
    spectrum = spectrum[valid_indices]

    eps = 1e-10  # Small constant for stability
    log_freqs = np.log(freqs[:m])
    log_spectrum = np.log(spectrum[:m] + eps)

    X = sm.add_constant(-2 * log_freqs)
    model = sm.OLS(log_spectrum, X).fit()

    d = model.params[1] / 2
    hurst_exp = d + 0.5

    return hurst_exp


  # Apply functions to each dataset
hurst_results_gph = {
    card: {
        "Hurst_GPH": gph_estimator(df["Log_Returns"]),

    }
    for card, df in log_returns.items()
}

# Convert to DataFrame for better visualization
hurst_df_gph = pd.DataFrame(hurst_results_gph).T
hurst_df_gph
# Out:
#                                                     Hurst_GPH
# weekly_data_aggregated_Charizard-Holo_#11_grade_9    0.435077
# weekly_data_aggregated_Charizard-Holo_#4_grade_...   0.478920
# weekly_data_aggregated_Charizard-Holo_#4_grade_...   0.406118
# weekly_data_aggregated_Charizard_GX_#9_grade_10      0.514788
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...   0.604624
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...   0.295768
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...   0.458987
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...   0.564974
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...   0.492442

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

def local_whittle_estimator(series, m=None):
    series = series.dropna().values  # Remove NaN values
    n = len(series)

    if m is None:
        m = int(n ** 0.8)  # Default bandwidth choice

    # Compute the Fourier frequencies
    freqs = (2 * np.pi * np.arange(1, m + 1)) / n  # Exclude zero frequency

    # Compute the periodogram
    fft_vals = np.fft.fft(series - np.mean(series))  # Demeaned FFT
    periodogram_vals = (np.abs(fft_vals[1:m + 1]) ** 2) / (n / 2)  # Correct normalization

    # Prevent log(0) issues
    eps = 1e-10
    log_freqs = np.log(freqs)
    log_periodogram = np.log(periodogram_vals + eps)  # Avoid log(0) issues

    # OLS regression to estimate d
    X = sm.add_constant(-2 * log_freqs)  # -2 * log(freq) as explanatory variable
    model = sm.OLS(log_periodogram, X).fit()

    d_estimate = model.params[1] / 2  # Estimate of fractional differencing parameter

    hurst_exp = d_estimate + 0.5  # Convert d to Hurst exponent

    return hurst_exp

# Apply function to each Pokémon card dataset
hurst_results_whittle = {
    card: {
        "Hurst_LW": local_whittle_estimator(df["Log_Returns"])  # Apply Local Whittle
    }
    for card, df in log_returns.items()
}

# Convert to DataFrame for better visualization
hurst_df_whittle = pd.DataFrame(hurst_results_whittle).T  # Transpose for readability

hurst_df_whittle
# Out:
#                                                     Hurst_LW
# weekly_data_aggregated_Charizard-Holo_#11_grade_9   0.290372
# weekly_data_aggregated_Charizard-Holo_#4_grade_...  0.367479
# weekly_data_aggregated_Charizard-Holo_#4_grade_...  0.410069
# weekly_data_aggregated_Charizard_GX_#9_grade_10     0.288198
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...  0.457975
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...  0.388883
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...  0.481805
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...  0.317092
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...  0.361169

# %% [markdown]
# # NOW fractal dimension:

# %% [markdown]
# # !! USE THE FOLLOWING FRACTAL DIMENSIONS (the most refined):

# %%
import numpy as np
import pandas as pd
from scipy.stats import linregress

# **Hall–Wood Fractal Dimension**
def hall_wood_fd(series):
    series = series.dropna().values  # Remove NaN values
    N = len(series)

    if N < 20:  # Skip very short series
        return np.nan

    scales = np.arange(2, min(20, N // 3))  # Use more scales for stability
    log_scales = np.log(scales)
    log_vars = []

    eps = 1e-10  # Small constant to prevent log(0)

    for scale in scales:
        chunks = [series[i:i + scale] for i in range(0, N - scale + 1, scale)]
        chunk_vars = [np.var(chunk) for chunk in chunks if len(chunk) == scale]

        if len(chunk_vars) > 0:
            log_vars.append(np.log(np.mean(chunk_vars) + eps))

    if len(log_vars) < 2:
        return np.nan  # Not enough data points for regression

    log_scales = log_scales[:len(log_vars)]  # Ensure matching lengths
    slope, _, _, _, _ = linregress(log_scales, log_vars)

    return 2 - slope  # Fractal Dimension D

# **Genton Fractal Dimension**
def genton_fd(series):
    series = series.dropna().values  # Remove NaN values
    N = len(series)

    if N < 20:
        return np.nan

    scales = np.arange(2, min(20, N // 3))  # More scales
    log_scales = np.log(scales)
    log_range = []

    eps = 1e-10  # Small constant for stability

    for scale in scales:
        chunks = [series[i:i + scale] for i in range(0, N - scale + 1, scale)]
        chunk_ranges = [np.percentile(chunk, 75) - np.percentile(chunk, 25) for chunk in chunks if len(chunk) == scale]  # Use IQR

        if len(chunk_ranges) > 0:
            log_range.append(np.log(np.mean(chunk_ranges) + eps))

    if len(log_range) < 2:
        return np.nan  # Not enough data points for regression

    log_scales = log_scales[:len(log_range)]  # Ensure matching lengths
    slope, _, _, _, _ = linregress(log_scales, log_range)

    return 2 - slope  # Fractal Dimension D

# **Apply both estimators to all datasets**
fractal_results = {
    card: {
        "Hall_Wood_FD": hall_wood_fd(df["Log_Returns"]),
        "Genton_FD": genton_fd(df["Log_Returns"])
    }
    for card, df in log_returns.items()
}

# Convert to DataFrame for visualization
fractal_df = pd.DataFrame(fractal_results).T
fractal_df
# Out:
#                                                     Hall_Wood_FD  Genton_FD
# weekly_data_aggregated_Charizard-Holo_#11_grade_9       1.898380   1.959747
# weekly_data_aggregated_Charizard-Holo_#4_grade_...      1.902332   1.873357
# weekly_data_aggregated_Charizard-Holo_#4_grade_...      1.881985   1.930387
# weekly_data_aggregated_Charizard_GX_#9_grade_10         1.851629   1.908126
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...      1.851156   1.846044
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...      1.868915   1.828421
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...      1.844801   1.970871
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...      1.909754   1.895090
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...      1.913229   1.963094

# %% [markdown]
# # !! USE THE FOLLOWING ONLY FOR THE APPROX. ENTROPY:

# %%
import numpy as np
import pandas as pd

# Function to compute Approximate Entropy (ApEn)
def approximate_entropy(series, m=2, r=None):
    series = series.dropna().values  # Remove NaNs
    N = len(series)

    eps = 1e-10  # Small constant for numerical stability

    if N < m + 1:
        return np.nan  # Not enough data

    if r is None:
        r = 0.2 * np.std(series)  # Set default tolerance

    # Create patterns
    patterns_m = np.array([series[i:i + m] for i in range(N - m + 1)])
    patterns_m1 = np.array([series[i:i + m + 1] for i in range(N - m)])

    def phi(patterns):
        distances = np.abs(patterns[:, None, :] - patterns[None, :, :]).max(axis=2)
        C = np.sum(distances <= r, axis=1) / (N - len(patterns) + 1)
        return np.mean(np.log(C + eps))  # Prevent log(0) errors

    return abs(phi(patterns_m) - phi(patterns_m1))  # ApEn formula

# **Apply to all datasets**
approx_entropy_results = {
    card: approximate_entropy(df["Log_Returns"])
    for card, df in log_returns.items()
}

# Convert to DataFrame for better visualization
approx_entropy_df = pd.DataFrame.from_dict(approx_entropy_results, orient="index", columns=["Approx_Entropy"])

approx_entropy_df
# Out:
#                                                     Approx_Entropy
# weekly_data_aggregated_Charizard-Holo_#11_grade_9         1.540576
# weekly_data_aggregated_Charizard-Holo_#4_grade_...        1.499729
# weekly_data_aggregated_Charizard-Holo_#4_grade_...        1.517454
# weekly_data_aggregated_Charizard_GX_#9_grade_10           1.479847
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...        1.410902
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...        1.261148
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...        1.352699
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...        1.384998
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...        1.596132

# %% [markdown]
# # Now finally the efficiency index:

# %% [markdown]
# # !! USE THE FOLLOWING FOR EI - THE BEST CURATED:

# %%
import numpy as np
import pandas as pd

# Expected values for an efficient market
M_star = {
    "Hurst": 0.5,
    "Fractal_Dimension": 1.5,
    "Approx_Entropy": 1.0
}

# Ranges for normalization
R_values = {
    "Hurst": 1.0,  # Hurst exponent range [0,1]
    "Fractal_Dimension": 1.0,  # Fractal dimension range [1,2]
    "Approx_Entropy": 2.0  # Entropy range as per Kristoufek & Vosvrda
}

# Load efficiency measures into a DataFrame (Assuming these DataFrames ready)
efficiency_data = pd.DataFrame({
    "Hurst_GPH": hurst_df_gph["Hurst_GPH"],  # GPH estimator
    "Hurst_LW": hurst_df_whittle["Hurst_LW"],  # Local Whittle estimator
    "Hall_Wood_FD": fractal_df["Hall_Wood_FD"],
    "Genton_FD": fractal_df["Genton_FD"],
    "Approx_Entropy": approx_entropy_df["Approx_Entropy"]
})

# Compute Efficiency Index (EI) function
def compute_efficiency_index(row):
    EI_values = []

    # Compute separately for both Hurst estimators (GPH & Local Whittle)
    for hurst in ["Hurst_GPH", "Hurst_LW"]:
        EI_values.append(((row[hurst] - M_star["Hurst"]) / R_values["Hurst"])**2)

    # Compute separately for both Fractal Dimension estimators
    for fd in ["Hall_Wood_FD", "Genton_FD"]:
        EI_values.append(((row[fd] - M_star["Fractal_Dimension"]) / R_values["Fractal_Dimension"])**2)

    # Compute for Approximate Entropy
    EI_values.append(((row["Approx_Entropy"] - M_star["Approx_Entropy"]) / R_values["Approx_Entropy"])**2)

    # Final Efficiency Index calculation
    return np.sqrt(sum(EI_values))

# Apply function to all rows
efficiency_data["Efficiency_Index"] = efficiency_data.apply(compute_efficiency_index, axis=1)

efficiency_data
# Out:
#                                                     Hurst_GPH  Hurst_LW  \
# weekly_data_aggregated_Charizard-Holo_#11_grade_9    0.435077  0.290372
# weekly_data_aggregated_Charizard-Holo_#4_grade_...   0.478920  0.367479
# weekly_data_aggregated_Charizard-Holo_#4_grade_...   0.406118  0.410069
# weekly_data_aggregated_Charizard_GX_#9_grade_10      0.514788  0.288198
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...   0.604624  0.457975
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...   0.295768  0.388883
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...   0.458987  0.481805
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...   0.564974  0.317092
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...   0.492442  0.361169
#
#                                                     Hall_Wood_FD  Genton_FD  \
# weekly_data_aggregated_Charizard-Holo_#11_grade_9       1.898380   1.959747
# weekly_data_aggregated_Charizard-Holo_#4_grade_...      1.902332   1.873357
# weekly_data_aggregated_Charizard-Holo_#4_grade_...      1.881985   1.930387
# weekly_data_aggregated_Charizard_GX_#9_grade_10         1.851629   1.908126
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...      1.851156   1.846044
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...      1.868915   1.828421
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...      1.844801   1.970871
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...      1.909754   1.895090
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...      1.913229   1.963094
#
#                                                     Approx_Entropy  \
# weekly_data_aggregated_Charizard-Holo_#11_grade_9         1.540576
# weekly_data_aggregated_Charizard-Holo_#4_grade_...        1.499729
# weekly_data_aggregated_Charizard-Holo_#4_grade_...        1.517454
# weekly_data_aggregated_Charizard_GX_#9_grade_10           1.479847
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...        1.410902
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...        1.261148
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...        1.352699
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...        1.384998
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...        1.596132
#
#                                                     Efficiency_Index
# weekly_data_aggregated_Charizard-Holo_#11_grade_9           0.700920
# weekly_data_aggregated_Charizard-Holo_#4_grade_...          0.617822
# weekly_data_aggregated_Charizard-Holo_#4_grade_...          0.644195
# weekly_data_aggregated_Charizard_GX_#9_grade_10             0.626779
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...          0.545875
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...          0.561307
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...          0.611326
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...          0.631449
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...          0.702417

# %% [markdown]
# ## top functioning bootstrap (just wait 30 mins:):

# %%
import numpy as np
import pandas as pd

np.random.seed(11) #replicability

# Function to compute the Efficiency Index
def compute_efficiency_index(row, M_star, R_values):
    EI_values = []

    # Compute for both Hurst exponents
    for hurst in ["Hurst_GPH", "Hurst_LW"]:
        EI_values.append(((row[hurst] - M_star["Hurst"]) / R_values["Hurst"])**2)

    # Compute for both Fractal Dimensions
    for fd in ["Hall_Wood_FD", "Genton_FD"]:
        EI_values.append(((row[fd] - M_star["Fractal_Dimension"]) / R_values["Fractal_Dimension"])**2)

    # Compute for Approximate Entropy
    EI_values.append(((row["Approx_Entropy"] - M_star["Approx_Entropy"]) / R_values["Approx_Entropy"])**2)

    return np.sqrt(sum(EI_values))

# Define expected values and ranges for efficiency measures
M_star = {"Hurst": 0.5, "Fractal_Dimension": 1.5, "Approx_Entropy": 1}
R_values = {"Hurst": 1, "Fractal_Dimension": 1, "Approx_Entropy": 2}  # Entropy range is double

# Step 1: Compute original Efficiency Index
efficiency_data["Efficiency_Index"] = efficiency_data.apply(compute_efficiency_index, axis=1, M_star=M_star, R_values=R_values)

# Function to perform bootstrapping for a given card
def bootstrap_efficiency(log_returns, num_bootstraps=1000):
    n = len(log_returns)
    bootstrap_EI = []

    for _ in range(num_bootstraps):
        # Step 2: Generate a bootstrapped sample with replacement
        bootstrapped_series = np.random.choice(log_returns, size=n, replace=True)

        # Step 3: Compute Efficiency Index for bootstrapped series
        bootstrapped_measures = {
            "Hurst_GPH": gph_estimator(pd.Series(bootstrapped_series)),
            "Hurst_LW": local_whittle_estimator(pd.Series(bootstrapped_series)),
            "Hall_Wood_FD": hall_wood_fd(pd.Series(bootstrapped_series)),
            "Genton_FD": genton_fd(pd.Series(bootstrapped_series)),
            "Approx_Entropy": approximate_entropy(pd.Series(bootstrapped_series))
        }
        bootstrapped_EI = compute_efficiency_index(bootstrapped_measures, M_star, R_values)
        bootstrap_EI.append(bootstrapped_EI)

    return bootstrap_EI

# Apply bootstrapping to all cards
bootstrap_results = {}
for card, df in log_returns.items():
    bootstrap_EI_values = bootstrap_efficiency(df["Log_Returns"])

    # Step 5: Compute statistical significance
    q05, q95 = np.percentile(bootstrap_EI_values, [5, 95])
    original_EI = efficiency_data.loc[card, "Efficiency_Index"]

    # Compute p-value based on rank of original EI
    r = sum(bootstrap_EI_values < original_EI) + 1  # Rank of original EI
    p_value = 1 - 2 * abs(r / (len(bootstrap_EI_values) + 1) - 0.5)

    # Store results
    bootstrap_results[card] = {
        "EI": original_EI,
        "EI_Boot_Mean": np.mean(bootstrap_EI_values),
        "EI_Boot_SD": np.std(bootstrap_EI_values),
        "q05": q05,
        "q95": q95,
        "p_value": p_value
    }

# Convert results to DataFrame
bootstrap_results_df = pd.DataFrame.from_dict(bootstrap_results, orient="index")
bootstrap_results_df
# Out:
#                                                           EI  EI_Boot_Mean  \
# weekly_data_aggregated_Charizard-Holo_#11_grade_9   0.700920      0.623582
# weekly_data_aggregated_Charizard-Holo_#4_grade_...  0.617822      0.596243
# weekly_data_aggregated_Charizard-Holo_#4_grade_...  0.644195      0.589925
# weekly_data_aggregated_Charizard_GX_#9_grade_10     0.626779      0.542689
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...  0.545875      0.519910
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...  0.561307      0.453338
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...  0.611326      0.610965
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...  0.631449      0.484661
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...  0.702417      0.601330
#
#                                                     EI_Boot_SD       q05  \
# weekly_data_aggregated_Charizard-Holo_#11_grade_9     0.030552  0.571430
# weekly_data_aggregated_Charizard-Holo_#4_grade_...    0.027562  0.549780
# weekly_data_aggregated_Charizard-Holo_#4_grade_...    0.029808  0.540715
# weekly_data_aggregated_Charizard_GX_#9_grade_10       0.042348  0.473587
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...    0.039998  0.453829
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...    0.041213  0.389261
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...    0.057561  0.513025
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...    0.037225  0.423708
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...    0.031253  0.551845
#
#                                                          q95   p_value
# weekly_data_aggregated_Charizard-Holo_#11_grade_9   0.672004  0.011988
# weekly_data_aggregated_Charizard-Holo_#4_grade_...  0.640163  0.429570
# weekly_data_aggregated_Charizard-Holo_#4_grade_...  0.638103  0.057942
# weekly_data_aggregated_Charizard_GX_#9_grade_10     0.611668  0.049950
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...  0.586803  0.497502
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...  0.522337  0.011988
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...  0.707065  0.999001
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...  0.547149  0.000000
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...  0.652178  0.001998

# %%
# Compute the alternative inefficiency measure (distance in SDs)
bootstrap_results_df["↑distance↑"] = (
    abs(bootstrap_results_df["EI"] - bootstrap_results_df["EI_Boot_Mean"]) /
    bootstrap_results_df["EI_Boot_SD"]
)

# Sort by highest inefficiency (most inefficient cards first)
bootstrap_results_df = bootstrap_results_df.sort_values(by="↑distance↑", ascending=True)


bootstrap_results_df
# Out:
#                                                           EI  EI_Boot_Mean  \
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...  0.611326      0.610965
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...  0.545875      0.519910
# weekly_data_aggregated_Charizard-Holo_#4_grade_...  0.617822      0.596243
# weekly_data_aggregated_Charizard-Holo_#4_grade_...  0.644195      0.589925
# weekly_data_aggregated_Charizard_GX_#9_grade_10     0.626779      0.542689
# weekly_data_aggregated_Charizard-Holo_#11_grade_9   0.700920      0.623582
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...  0.561307      0.453338
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...  0.702417      0.601330
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...  0.631449      0.484661
#
#                                                     EI_Boot_SD       q05  \
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...    0.057561  0.513025
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...    0.039998  0.453829
# weekly_data_aggregated_Charizard-Holo_#4_grade_...    0.027562  0.549780
# weekly_data_aggregated_Charizard-Holo_#4_grade_...    0.029808  0.540715
# weekly_data_aggregated_Charizard_GX_#9_grade_10       0.042348  0.473587
# weekly_data_aggregated_Charizard-Holo_#11_grade_9     0.030552  0.571430
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...    0.041213  0.389261
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...    0.031253  0.551845
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...    0.037225  0.423708
#
#                                                          q95   p_value  \
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...  0.707065  0.999001
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...  0.586803  0.497502
# weekly_data_aggregated_Charizard-Holo_#4_grade_...  0.640163  0.429570
# weekly_data_aggregated_Charizard-Holo_#4_grade_...  0.638103  0.057942
# weekly_data_aggregated_Charizard_GX_#9_grade_10     0.611668  0.049950
# weekly_data_aggregated_Charizard-Holo_#11_grade_9   0.672004  0.011988
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...  0.522337  0.011988
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...  0.652178  0.001998
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...  0.547149  0.000000
#
#                                                     ↑distance↑
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...    0.006277
# weekly_data_aggregated_Full_ArtCharizard_GX_#SV...    0.649150
# weekly_data_aggregated_Charizard-Holo_#4_grade_...    0.782932
# weekly_data_aggregated_Charizard-Holo_#4_grade_...    1.820647
# weekly_data_aggregated_Charizard_GX_#9_grade_10       1.985699
# weekly_data_aggregated_Charizard-Holo_#11_grade_9     2.531315
# weekly_data_aggregated_Full_ArtCharizard_Vmax_#...    2.619776
# weekly_data_aggregated_Full_ArtM_Charizard_EX_#...    3.234491
# weekly_data_aggregated_Full_ArtMoltres_&_Zapdos...    3.943325

# %% [markdown]
#  Next Steps for Further Analysis
#
# Compare Inefficient Cards to Trading Volume
#
#     Do the most inefficient cards have the lowest liquidity?
#     Does high inefficiency correlate with low sales activity?
#
# Visualize Price Trajectories of Inefficient Cards
#
#     Do the most inefficient cards have erratic price spikes & drops?
#     If so, that confirms inefficiency.
#
# Check If Inefficiency Persists Over Time
#
#     Run the same bootstrapping analysis on monthly data.
#     If inefficiency disappears, markets may be inefficient in the short term but efficient in the long run.
